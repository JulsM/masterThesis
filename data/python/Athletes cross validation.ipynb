# %% [markdown]
# <b style='font-size: 13pt'>Julian Maurer: <br></b>
# Train set = kmeans, Evaluation = 4-fold cross validation

# %%
# %run raceTimePredictor.py
# Out:
# Load Data
# Start training
#
# Iteration  1
# train size:  65  test size:  4
# distance: 8011.9, elevation: 215.91, time: 31.75
# distance: 21089.2, elevation: 96.2066, time: 81.9833333333
# distance: 9880.0, elevation: 30.4297, time: 37.0333333333
# distance: 9971.4, elevation: 5.80692, time: 36.5166666667
# Train set evaluation
# Mean Squared Error: 9.32058 min
# Root Mean Squared Error: 2.89429 min
#
# Test set evaluation
# Mean Squared Error: 2.00315 min
# Root Mean Squared Error: 1.02931 min
#
# Iteration  2
# train size:  65  test size:  4
# distance: 9524.2, elevation: 125.393, time: 37.2833333333
# distance: 10071.1, elevation: 69.881, time: 37.9666666667
# distance: 5368.7, elevation: 76.8209, time: 19.5833333333
# distance: 5090.0, elevation: 38.4265, time: 18.45
# Train set evaluation
# Mean Squared Error: 9.20102 min
# Root Mean Squared Error: 2.86185 min
#
# Test set evaluation
# Mean Squared Error: 1.94802 min
# Root Mean Squared Error: 0.968072 min
#
# Iteration  3
# ...

# %% [markdown]
# Predictions:

# %%
# %run raceTimePredictor.py
# Out:
# Load Data
# train size:  69  test size:  11
# Start training
#
# Train set evaluation
# Mean Squared Error: 8.70747 min
# Root Mean Squared Error: 2.78448 min
#
# Test set evaluation
# Mean Squared Error: 39.8612 min
# Root Mean Squared Error: 6.23755 min
#
#
# Predictions
#
#      dist  elev  hilly   cs  atl  ctl  isRace  avgVo2max   time
# 0    5000     0    0.0  0.0   30   45       1  43.668147   17.5
# 1    5000    70    0.1  0.2   30   45       1  43.668147   19.0
# 2    5000   150    0.3  1.5   30   45       1  43.668147   22.0
# 3   10000     0    0.0  0.0   30   45       1  43.668147   36.5
# 4   10000    70    0.3  0.5   30   45       1  43.668147   39.0
# 5   10000   150    0.5  1.5   30   45       1  43.668147   41.0
# 6   21097     0    0.0  0.0   30   45       1  43.668147   79.0
# 7   21097    70    0.3  0.5   30   45       1  43.668147   81.0
# 8   21097   150    0.4  1.5   30   50       1  43.668147   85.0
# ...

# %% [markdown]
# With Pre-Training: <br>
# Pre-Train set = all activities of athletes, Train set = kmeans, Evaluation = 4-fold cross validation on train set

# %%
# %run raceTimePredictor.py
# Out:
# Pre-train Set
# train size:  5118
# Train kmeans
#
# Iteration  1
# train size:  65  test size:  4
# distance: 12317.6, elevation: 333.913, time: 59.4833333333
# distance: 5368.7, elevation: 76.8209, time: 19.5833333333
# distance: 5090.0, elevation: 38.4265, time: 18.45
# distance: 5048.4, elevation: 3.9124, time: 17.3166666667
# Train set evaluation
# Mean Squared Error: 9.45553 min
# Root Mean Squared Error: 2.87805 min
#
# Test set evaluation
# Mean Squared Error: 5.6549 min
# Root Mean Squared Error: 2.1172 min
#
# Iteration  2
# train size:  65  test size:  4
# distance: 8011.9, elevation: 215.91, time: 31.75
# distance: 9880.0, elevation: 30.4297, time: 37.0333333333
# distance: 9971.4, elevation: 5.80692, time: 36.5166666667
# distance: 9524.2, elevation: 125.393, time: 37.2833333333
# Train set evaluation
# Mean Squared Error: 9.76635 min
# Root Mean Squared Error: 2.93005 min
#
# Test set evaluation
# Mean Squared Error: 1.59073 min
# Root Mean Squared Error: 0.639981 min
# ...

# %% [markdown]
# <b style='font-size: 13pt'>Florian Daiber: <br></b>
# Train set = kmeans, Evaluation = 2-fold cross validation

# %%
# %run raceTimePredictor.py
# Out:
# Load Data
# Start training
#
# Iteration  1
# train size:  202  test size:  2
# distance: 42237.3, elevation: 173.825, time: 209.716666667
# distance: 5034.5, elevation: 3.85522, time: 18.9333333333
# Train set evaluation
# Mean Squared Error: 19.1023 min
# Root Mean Squared Error: 4.49808 min
#
# Test set evaluation
# Mean Squared Error: 247.662 min
# Root Mean Squared Error: 15.6951 min
#
# Iteration  2
# train size:  202  test size:  2
# distance: 9072.4, elevation: 428.017, time: 42.6166666667
# distance: 9890.2, elevation: 145.475, time: 39.3833333333
# Train set evaluation
# Mean Squared Error: 19.8839 min
# Root Mean Squared Error: 4.57709 min
#
# Test set evaluation
# Mean Squared Error: 78.7202 min
# Root Mean Squared Error: 8.79517 min
#
#
# Mean MSE for 2-fold cross validation: 163.191
# Mean RMSE for 2-fold cross validation: 12.2452

# %% [markdown]
# Predictions:

# %%
# %run raceTimePredictor.py
# Out:
# Load Data
# train size:  207  test size:  11
# Start training
#
# Train set evaluation
# Mean Squared Error: 21.3465 min
# Root Mean Squared Error: 4.67803 min
#
# Test set evaluation
# Mean Squared Error: 208.936 min
# Root Mean Squared Error: 14.4027 min
#
#
# Predictions
#
#      dist  elev  hilly   cs  atl  ctl  isRace  avgVo2max   time
# 0    5000     0    0.0  0.0   30   45       1  31.650242   17.5
# 1    5000    70    0.1  0.2   30   45       1  31.650242   19.0
# 2    5000   150    0.3  1.5   30   45       1  31.650242   22.0
# 3   10000     0    0.0  0.0   30   45       1  31.650242   36.5
# 4   10000    70    0.3  0.5   30   45       1  31.650242   39.0
# 5   10000   150    0.5  1.5   30   45       1  31.650242   41.0
# 6   21097     0    0.0  0.0   30   45       1  31.650242   79.0
# 7   21097    70    0.3  0.5   30   45       1  31.650242   81.0
# 8   21097   150    0.4  1.5   30   50       1  31.650242   85.0
# ...

# %% [markdown]
# With Pre-Training: <br>
# Pre-Train set = all activities of athletes, Train set = kmeans, Evaluation = 2-fold cross validation on train set

# %%
# %run raceTimePredictor.py
# Out:
# Pre-train Set
# train size:  5118
# Train kmeans
#
# Iteration  1
# train size:  205  test size:  2
# distance: 9072.4, elevation: 428.017, time: 42.6166666667
# distance: 5034.5, elevation: 3.85522, time: 18.9333333333
# Train set evaluation
# Mean Squared Error: 20.2466 min
# Root Mean Squared Error: 4.49452 min
#
# Test set evaluation
# Mean Squared Error: 11.024 min
# Root Mean Squared Error: 2.96249 min
#
# Iteration  2
# train size:  205  test size:  2
# distance: 9890.2, elevation: 145.475, time: 39.3833333333
# distance: 42237.3, elevation: 173.825, time: 209.716666667
# Train set evaluation
# Mean Squared Error: 20.2812 min
# Root Mean Squared Error: 4.48377 min
#
# Test set evaluation
# Mean Squared Error: 94.6061 min
# Root Mean Squared Error: 9.62065 min
#
#
# Mean MSE for 2-fold cross validation: 52.8151 min
# Mean RMSE for 2-fold cross validation: 6.29157 min

# %% [markdown]
# <b style='font-size: 13pt'>Joachim Groß: <br></b>
# Train set = kmeans, Evaluation = 4-fold cross validation

# %%
# %run raceTimePredictor.py
# Out:
# Load Data
# Start training
#
# Iteration  1
# train size:  117  test size:  4
# distance: 5140.1, elevation: 6.85031, time: 18.8833333333
# distance: 9934.2, elevation: 50.3259, time: 38.8
# distance: 12053.9, elevation: 102.352, time: 63.6833333333
# distance: 4149.5, elevation: 103.351, time: 15.7333333333
# Train set evaluation
# Mean Squared Error: 34.0382 min
# Root Mean Squared Error: 5.55458 min
#
# Test set evaluation
# Mean Squared Error: 40.0831 min
# Root Mean Squared Error: 6.0744 min
#
# Iteration  2
# train size:  117  test size:  4
# distance: 21159.9, elevation: 50.118, time: 84.6
# distance: 10036.4, elevation: 70.0226, time: 46.1
# distance: 8172.6, elevation: 208.684, time: 32.35
# distance: 22182.8, elevation: 53.0228, time: 93.3166666667
# Train set evaluation
# Mean Squared Error: 33.6609 min
# Root Mean Squared Error: 5.53263 min
#
# Test set evaluation
# Mean Squared Error: 50.0559 min
# Root Mean Squared Error: 6.85601 min
#
# Iteration  3
# ...

# %% [markdown]
# Predictions:

# %%
# %run raceTimePredictor.py
# Out:
# Load Data
# train size:  121  test size:  11
# Start training
#
# Train set evaluation
# Mean Squared Error: 34.1708 min
# Root Mean Squared Error: 5.58278 min
#
# Test set evaluation
# Mean Squared Error: 130.878 min
# Root Mean Squared Error: 11.3082 min
#
#
# Predictions
#
#      dist  elev  hilly   cs  atl  ctl  isRace  avgVo2max   time
# 0    5000     0    0.0  0.0   30   45       1  38.466257   17.5
# 1    5000    70    0.1  0.2   30   45       1  38.466257   19.0
# 2    5000   150    0.3  1.5   30   45       1  38.466257   22.0
# 3   10000     0    0.0  0.0   30   45       1  38.466257   36.5
# 4   10000    70    0.3  0.5   30   45       1  38.466257   39.0
# 5   10000   150    0.5  1.5   30   45       1  38.466257   41.0
# 6   21097     0    0.0  0.0   30   45       1  38.466257   79.0
# 7   21097    70    0.3  0.5   30   45       1  38.466257   81.0
# 8   21097   150    0.4  1.5   30   50       1  38.466257   85.0
# ...

# %% [markdown]
# With Pre-Training: <br>
# Pre-Train set = all activities of athletes, Train set = kmeans, Evaluation = 4-fold cross validation on train set

# %%
# %run raceTimePredictor.py
# Out:
# Pre-train Set
# train size:  5120
# Train kmeans
#
# Iteration  1
# train size:  117  test size:  4
# distance: 5140.1, elevation: 6.85031, time: 18.8833333333
# distance: 9934.2, elevation: 50.3259, time: 38.8
# distance: 12053.9, elevation: 102.352, time: 63.6833333333
# distance: 4149.5, elevation: 103.351, time: 15.7333333333
# Train set evaluation
# Mean Squared Error: 42.862 min
# Root Mean Squared Error: 6.22127 min
#
# Test set evaluation
# Mean Squared Error: 47.5243 min
# Root Mean Squared Error: 6.58532 min
#
# Iteration  2
# train size:  117  test size:  4
# distance: 21159.9, elevation: 50.118, time: 84.6
# distance: 10036.4, elevation: 70.0226, time: 46.1
# distance: 8172.6, elevation: 208.684, time: 32.35
# distance: 22182.8, elevation: 53.0228, time: 93.3166666667
# Train set evaluation
# Mean Squared Error: 42.88 min
# Root Mean Squared Error: 6.23417 min
#
# Test set evaluation
# Mean Squared Error: 45.1241 min
# Root Mean Squared Error: 6.41163 min
#
# ...

# %% [markdown]
# <b style='font-size: 13pt'>Kerstin de Vries: <br></b>
# Train set = kmeans, Evaluation = 2-fold cross validation

# %%
# %run raceTimePredictor.py
# Out:
# Load Data
# Start training
#
# Iteration  1
# train size:  106  test size:  2
# distance: 21018.2, elevation: 122.704, time: 102.25
# distance: 10205.6, elevation: 10.0834, time: 43.4333333333
# Train set evaluation
# Mean Squared Error: 40.1354 min
# Root Mean Squared Error: 5.90693 min
#
# Test set evaluation
# Mean Squared Error: 751.959 min
# Root Mean Squared Error: 27.3261 min
#
# Iteration  2
# train size:  106  test size:  2
# distance: 45850.1, elevation: 76.367, time: 209.183333333
# distance: 44151.2, elevation: 60.0, time: 214.616666667
# Train set evaluation
# Mean Squared Error: 42.4259 min
# Root Mean Squared Error: 6.27721 min
#
# Test set evaluation
# Mean Squared Error: 1029.94 min
# Root Mean Squared Error: 32.0456 min
#
#
# Mean MSE for 2-fold cross validation: 890.952
# Mean RMSE for 2-fold cross validation: 29.6859

# %% [markdown]
# Predictions:

# %%
# %run raceTimePredictor.py
# Out:
# Load Data
# train size:  108  test size:  11
# Start training
#
# Train set evaluation
# Mean Squared Error: 40.0846 min
# Root Mean Squared Error: 5.85279 min
#
# Test set evaluation
# Mean Squared Error: 218.897 min
# Root Mean Squared Error: 14.5968 min
#
#
# Predictions
#
#      dist  elev  hilly   cs  atl  ctl  isRace  avgVo2max   time
# 0    5000     0    0.0  0.0   30   45       1  34.981749   17.5
# 1    5000    70    0.1  0.2   30   45       1  34.981749   19.0
# 2    5000   150    0.3  1.5   30   45       1  34.981749   22.0
# 3   10000     0    0.0  0.0   30   45       1  34.981749   36.5
# 4   10000    70    0.3  0.5   30   45       1  34.981749   39.0
# 5   10000   150    0.5  1.5   30   45       1  34.981749   41.0
# 6   21097     0    0.0  0.0   30   45       1  34.981749   79.0
# 7   21097    70    0.3  0.5   30   45       1  34.981749   81.0
# 8   21097   150    0.4  1.5   30   50       1  34.981749   85.0
# ...

# %% [markdown]
# With Pre-Training: <br>
# Pre-Train set = all activities of athletes, Train set = kmeans, Evaluation = 2-fold cross validation on train set

# %%
# %run raceTimePredictor.py
# Out:
# Pre-train Set
# train size:  5119
# Train kmeans
#
# Iteration  1
# train size:  106  test size:  2
# distance: 21018.2, elevation: 122.704, time: 102.25
# distance: 10205.6, elevation: 10.0834, time: 43.4333333333
# Train set evaluation
# Mean Squared Error: 43.6456 min
# Root Mean Squared Error: 6.37952 min
#
# Test set evaluation
# Mean Squared Error: 787.564 min
# Root Mean Squared Error: 28.011 min
#
# Iteration  2
# train size:  106  test size:  2
# distance: 45850.1, elevation: 76.367, time: 209.183333333
# distance: 44151.2, elevation: 60.0, time: 214.616666667
# Train set evaluation
# Mean Squared Error: 41.9157 min
# Root Mean Squared Error: 6.27346 min
#
# Test set evaluation
# Mean Squared Error: 957.337 min
# Root Mean Squared Error: 30.8995 min
#
#
# Mean MSE for 2-fold cross validation: 872.45 min
# Mean RMSE for 2-fold cross validation: 29.4552 min

# %% [markdown]
# <b style='font-size: 13pt'>Tom Holzweg: <br></b>
# Train set = kmeans, Evaluation = 4-fold cross validation

# %%
# %run raceTimePredictor.py
# Out:
# Load Data
# Start training
#
# Iteration  1
# train size:  111  test size:  2
# distance: 42631.3, elevation: 57.909, time: 207.25
# distance: 25534.4, elevation: 129.312, time: 129.466666667
# Train set evaluation
# Mean Squared Error: 27.7681 min
# Root Mean Squared Error: 5.04764 min
#
# Test set evaluation
# Mean Squared Error: 15.0623 min
# Root Mean Squared Error: 3.57393 min
#
# Iteration  2
# train size:  111  test size:  2
# distance: 4570.0, elevation: 31.5504, time: 21.6
# distance: 23840.6, elevation: 204.143, time: 123.933333333
# Train set evaluation
# Mean Squared Error: 28.2955 min
# Root Mean Squared Error: 5.08446 min
#
# Test set evaluation
# Mean Squared Error: 5.96098 min
# Root Mean Squared Error: 1.87542 min
#
# Iteration  3
# train size:  111  test size:  2
# distance: 4270.9, elevation: 321.102, time: 26.8833333333
# distance: 4815.6, elevation: 441.066, time: 33.9833333333
# Train set evaluation
# Mean Squared Error: 28.0022 min
# ...

# %% [markdown]
# Predictions:

# %%
# %run raceTimePredictor.py
# Out:
# Load Data
# train size:  113  test size:  11
# Start training
#
# Train set evaluation
# Mean Squared Error: 27.986 min
# Root Mean Squared Error: 5.06349 min
#
# Test set evaluation
# Mean Squared Error: 272.559 min
# Root Mean Squared Error: 16.4381 min
#
#
# Predictions
#
#      dist  elev  hilly   cs  atl  ctl  isRace  avgVo2max   time
# 0    5000     0    0.0  0.0   30   45       1  36.580407   17.5
# 1    5000    70    0.1  0.2   30   45       1  36.580407   19.0
# 2    5000   150    0.3  1.5   30   45       1  36.580407   22.0
# 3   10000     0    0.0  0.0   30   45       1  36.580407   36.5
# 4   10000    70    0.3  0.5   30   45       1  36.580407   39.0
# 5   10000   150    0.5  1.5   30   45       1  36.580407   41.0
# 6   21097     0    0.0  0.0   30   45       1  36.580407   79.0
# 7   21097    70    0.3  0.5   30   45       1  36.580407   81.0
# 8   21097   150    0.4  1.5   30   50       1  36.580407   85.0
# ...

# %% [markdown]
# With Pre-Training: <br>
# Pre-Train set = all activities of athletes, Train set = kmeans, Evaluation = 4-fold cross validation on train set

# %%
# %run raceTimePredictor.py
# Out:
# Pre-train Set
# train size:  5120
# Train kmeans
#
# Iteration  1
# train size:  111  test size:  2
# distance: 42631.3, elevation: 57.909, time: 207.25
# distance: 25534.4, elevation: 129.312, time: 129.466666667
# Train set evaluation
# Mean Squared Error: 23.554 min
# Root Mean Squared Error: 4.58334 min
#
# Test set evaluation
# Mean Squared Error: 299.978 min
# Root Mean Squared Error: 17.2462 min
#
# Iteration  2
# train size:  111  test size:  2
# distance: 4570.0, elevation: 31.5504, time: 21.6
# distance: 23840.6, elevation: 204.143, time: 123.933333333
# Train set evaluation
# Mean Squared Error: 24.3099 min
# Root Mean Squared Error: 4.64701 min
#
# Test set evaluation
# Mean Squared Error: 36.4019 min
# Root Mean Squared Error: 5.80403 min
#
# Iteration  3
# train size:  111  test size:  2
# distance: 4270.9, elevation: 321.102, time: 26.8833333333
# distance: 4815.6, elevation: 441.066, time: 33.9833333333
# Train set evaluation
# Mean Squared Error: 24.8897 min
# ...

# %% [markdown]
# <b style='font-size: 13pt'>Thomas Buyse: <br></b>
# Train set = kmeans, Evaluation = 4-fold cross validation

# %%
# %run raceTimePredictor.py
# Out:
# Load Data
# Start training
#
# Iteration  1
# train size:  53  test size:  3
# distance: 6270.5, elevation: 221.62, time: 36.1666666667
# distance: 7158.3, elevation: 19.4459, time: 31.0666666667
# distance: 12780.5, elevation: 125.561, time: 54.6166666667
# Train set evaluation
# Mean Squared Error: 9.67619 min
# Root Mean Squared Error: 2.76866 min
#
# Test set evaluation
# Mean Squared Error: 19.5159 min
# Root Mean Squared Error: 4.18392 min
#
# Iteration  2
# train size:  53  test size:  3
# distance: 18949.7, elevation: 582.111, time: 105.466666667
# distance: 10211.6, elevation: 46.8074, time: 41.4333333333
# distance: 15925.9, elevation: 96.651, time: 67.2333333333
# Train set evaluation
# Mean Squared Error: 12.9117 min
# Root Mean Squared Error: 3.43549 min
#
# Test set evaluation
# Mean Squared Error: 24.3763 min
# Root Mean Squared Error: 4.82361 min
#
# Iteration  3
# train size:  53  test size:  3
# distance: 10027.0, elevation: 3.94326, time: 39.0833333333
# ...

# %% [markdown]
# Predictions:

# %%
# %run raceTimePredictor.py
# Out:
# Load Data
# train size:  56  test size:  11
# Start training
#
# Train set evaluation
# Mean Squared Error: 9.5458 min
# Root Mean Squared Error: 2.79568 min
#
# Test set evaluation
# Mean Squared Error: 23.9181 min
# Root Mean Squared Error: 4.71043 min
#
#
# Predictions
#
#      dist  elev  hilly   cs  atl  ctl  isRace  avgVo2max   time
# 0    5000     0    0.0  0.0   30   45       1    36.2311   17.5
# 1    5000    70    0.1  0.2   30   45       1    36.2311   19.0
# 2    5000   150    0.3  1.5   30   45       1    36.2311   22.0
# 3   10000     0    0.0  0.0   30   45       1    36.2311   36.5
# 4   10000    70    0.3  0.5   30   45       1    36.2311   39.0
# 5   10000   150    0.5  1.5   30   45       1    36.2311   41.0
# 6   21097     0    0.0  0.0   30   45       1    36.2311   79.0
# 7   21097    70    0.3  0.5   30   45       1    36.2311   81.0
# 8   21097   150    0.4  1.5   30   50       1    36.2311   85.0
# ...

# %% [markdown]
# With Pre-Training: <br>
# Pre-Train set = all activities of athletes, Train set = kmeans, Evaluation = 4-fold cross validation on train set

# %%
# %run raceTimePredictor.py
# Out:
# Pre-train Set
# train size:  5120
# Train kmeans
#
# Iteration  1
# train size:  53  test size:  3
# distance: 6270.5, elevation: 221.62, time: 36.1666666667
# distance: 7158.3, elevation: 19.4459, time: 31.0666666667
# distance: 12780.5, elevation: 125.561, time: 54.6166666667
# Train set evaluation
# Mean Squared Error: 10.2695 min
# Root Mean Squared Error: 3.02713 min
#
# Test set evaluation
# Mean Squared Error: 7.14759 min
# Root Mean Squared Error: 2.45797 min
#
# Iteration  2
# train size:  53  test size:  3
# distance: 18949.7, elevation: 582.111, time: 105.466666667
# distance: 10211.6, elevation: 46.8074, time: 41.4333333333
# distance: 15925.9, elevation: 96.651, time: 67.2333333333
# Train set evaluation
# Mean Squared Error: 10.1096 min
# Root Mean Squared Error: 3.01497 min
#
# Test set evaluation
# Mean Squared Error: 18.6058 min
# Root Mean Squared Error: 4.1936 min
#
# Iteration  3
# train size:  53  test size:  3
# ...

# %% [markdown]
# <b style='font-size: 13pt'>Torsten Kohlwey: <br></b>
# Train set = kmeans, Evaluation = 4-fold cross validation

# %%
# %run raceTimePredictor.py
# Out:
# Load Data
# Start training
#
# Iteration  1
# train size:  116  test size:  2
# distance: 9842.7, elevation: 42.7969, time: 47.7833333333
# distance: 10118.1, elevation: 22.2997, time: 43.7
# Train set evaluation
# Mean Squared Error: 22.2515 min
# Root Mean Squared Error: 4.4845 min
#
# Test set evaluation
# Mean Squared Error: 7.45408 min
# Root Mean Squared Error: 2.30507 min
#
# Iteration  2
# train size:  116  test size:  2
# distance: 9908.6, elevation: 139.026, time: 44.6166666667
# distance: 5574.3, elevation: 118.917, time: 29.0166666667
# Train set evaluation
# Mean Squared Error: 22.4555 min
# Root Mean Squared Error: 4.51516 min
#
# Test set evaluation
# Mean Squared Error: 3.6294 min
# Root Mean Squared Error: 1.24924 min
#
# Iteration  3
# train size:  116  test size:  2
# distance: 3979.7, elevation: 98.8882, time: 17.9166666667
# distance: 21006.1, elevation: 49.2529, time: 94.7333333333
# Train set evaluation
# Mean Squared Error: 22.1438 min
# ...

# %% [markdown]
# Predictions:

# %%
# %run raceTimePredictor.py
# Out:
# Load Data
# train size:  118  test size:  11
# Start training
#
# Train set evaluation
# Mean Squared Error: 25.4204 min
# Root Mean Squared Error: 4.9046 min
#
# Test set evaluation
# Mean Squared Error: 196.125 min
# Root Mean Squared Error: 13.9557 min
#
#
# Predictions
#
#      dist  elev  hilly   cs  atl  ctl  isRace  avgVo2max   time
# 0    5000     0    0.0  0.0   30   45       1  31.319756   17.5
# 1    5000    70    0.1  0.2   30   45       1  31.319756   19.0
# 2    5000   150    0.3  1.5   30   45       1  31.319756   22.0
# 3   10000     0    0.0  0.0   30   45       1  31.319756   36.5
# 4   10000    70    0.3  0.5   30   45       1  31.319756   39.0
# 5   10000   150    0.5  1.5   30   45       1  31.319756   41.0
# 6   21097     0    0.0  0.0   30   45       1  31.319756   79.0
# 7   21097    70    0.3  0.5   30   45       1  31.319756   81.0
# 8   21097   150    0.4  1.5   30   50       1  31.319756   85.0
# ...

# %% [markdown]
# With Pre-Training: <br>
# Pre-Train set = all activities of athletes, Train set = kmeans, Evaluation = 4-fold cross validation on train set

# %%
# %run raceTimePredictor.py
# Out:
# Pre-train Set
# train size:  5120
# Train kmeans
#
# Iteration  1
# train size:  116  test size:  2
# distance: 9842.7, elevation: 42.7969, time: 47.7833333333
# distance: 10118.1, elevation: 22.2997, time: 43.7
# Train set evaluation
# Mean Squared Error: 23.1235 min
# Root Mean Squared Error: 4.58415 min
#
# Test set evaluation
# Mean Squared Error: 4.13084 min
# Root Mean Squared Error: 1.42189 min
#
# Iteration  2
# train size:  116  test size:  2
# distance: 9908.6, elevation: 139.026, time: 44.6166666667
# distance: 5574.3, elevation: 118.917, time: 29.0166666667
# Train set evaluation
# Mean Squared Error: 22.4784 min
# Root Mean Squared Error: 4.5189 min
#
# Test set evaluation
# Mean Squared Error: 4.63288 min
# Root Mean Squared Error: 1.60468 min
#
# Iteration  3
# train size:  116  test size:  2
# distance: 3979.7, elevation: 98.8882, time: 17.9166666667
# distance: 21006.1, elevation: 49.2529, time: 94.7333333333
# Train set evaluation
# Mean Squared Error: 22.0591 min
# ...

# %% [markdown]
# <b style='font-size: 13pt'>Markus Pfarrkircher: <br></b>
# Train set = kmeans, Evaluation = 4-fold cross validation

# %%
# %run raceTimePredictor.py
# Out:
# Load Data
# Start training
#
# Iteration  1
# train size:  47  test size:  2
# distance: 10007.0, elevation: 27.3427, time: 53.1333333333
# distance: 21149.3, elevation: 40.8708, time: 123.65
# Train set evaluation
# Mean Squared Error: 18.1519 min
# Root Mean Squared Error: 4.0853 min
#
# Test set evaluation
# Mean Squared Error: 83.4905 min
# Root Mean Squared Error: 9.05695 min
#
# Iteration  2
# train size:  47  test size:  2
# distance: 9989.9, elevation: 189.435, time: 55.2166666667
# distance: 6759.8, elevation: 33.8767, time: 32.6666666667
# Train set evaluation
# Mean Squared Error: 16.3995 min
# Root Mean Squared Error: 3.57521 min
#
# Test set evaluation
# Mean Squared Error: 17.4456 min
# Root Mean Squared Error: 3.71863 min
#
# Iteration  3
# train size:  47  test size:  2
# distance: 9910.5, elevation: 49.3492, time: 49.2166666667
# distance: 11816.0, elevation: 332.648, time: 66.2166666667
# Train set evaluation
# Mean Squared Error: 19.5768 min
# ...

# %% [markdown]
# Predictions:

# %%
# %run raceTimePredictor.py
# Out:
# Load Data
# train size:  49  test size:  11
# Start training
#
# Train set evaluation
# Mean Squared Error: 19.9665 min
# Root Mean Squared Error: 4.23133 min
#
# Test set evaluation
# Mean Squared Error: 543.271 min
# Root Mean Squared Error: 23.2639 min
#
#
# Predictions
#
#      dist  elev  hilly   cs  atl  ctl  isRace  avgVo2max   time
# 0    5000     0    0.0  0.0   30   45       1   32.73448   17.5
# 1    5000    70    0.1  0.2   30   45       1   32.73448   19.0
# 2    5000   150    0.3  1.5   30   45       1   32.73448   22.0
# 3   10000     0    0.0  0.0   30   45       1   32.73448   36.5
# 4   10000    70    0.3  0.5   30   45       1   32.73448   39.0
# 5   10000   150    0.5  1.5   30   45       1   32.73448   41.0
# 6   21097     0    0.0  0.0   30   45       1   32.73448   79.0
# 7   21097    70    0.3  0.5   30   45       1   32.73448   81.0
# 8   21097   150    0.4  1.5   30   50       1   32.73448   85.0
# ...

# %% [markdown]
# With Pre-Training: <br>
# Pre-Train set = all activities of athletes, Train set = kmeans, Evaluation = 4-fold cross validation on train set

# %%
# %run raceTimePredictor.py
# Out:
# Pre-train Set
# train size:  5120
# Train kmeans
#
# Iteration  1
# train size:  47  test size:  2
# distance: 10007.0, elevation: 27.3427, time: 53.1333333333
# distance: 21149.3, elevation: 40.8708, time: 123.65
# Train set evaluation
# Mean Squared Error: 13.3217 min
# Root Mean Squared Error: 3.05449 min
#
# Test set evaluation
# Mean Squared Error: 116.901 min
# Root Mean Squared Error: 10.6259 min
#
# Iteration  2
# train size:  47  test size:  2
# distance: 9989.9, elevation: 189.435, time: 55.2166666667
# distance: 6759.8, elevation: 33.8767, time: 32.6666666667
# Train set evaluation
# Mean Squared Error: 15.1919 min
# Root Mean Squared Error: 3.28066 min
#
# Test set evaluation
# Mean Squared Error: 9.06721 min
# Root Mean Squared Error: 2.1536 min
#
# Iteration  3
# train size:  47  test size:  2
# distance: 9910.5, elevation: 49.3492, time: 49.2166666667
# distance: 11816.0, elevation: 332.648, time: 66.2166666667
# Train set evaluation
# Mean Squared Error: 14.2905 min
# ...

# %% [markdown]
# <b style='font-size: 13pt'>Alexander Lüdemann: <br></b>
# Train set = kmeans, Evaluation = 4-fold cross validation

# %%
# %run raceTimePredictor.py
# Out:
# Load Data
# Start training
#
# Iteration  1
# train size:  139  test size:  2
# distance: 5083.2, elevation: 3.9973, time: 20.1166666667
# distance: 9989.7, elevation: 35.8716, time: 42.0666666667
# Train set evaluation
# Mean Squared Error: 31.1636 min
# Root Mean Squared Error: 7.06107 min
#
# Test set evaluation
# Mean Squared Error: 7.75055 min
# Root Mean Squared Error: 2.35237 min
#
# Iteration  2
# train size:  139  test size:  2
# distance: 10032.0, elevation: 10.2774, time: 42.5666666667
# distance: 21049.6, elevation: 57.7658, time: 91.2333333333
# Train set evaluation
# Mean Squared Error: 30.3665 min
# Root Mean Squared Error: 6.62957 min
#
# Test set evaluation
# Mean Squared Error: 7.32956 min
# Root Mean Squared Error: 1.71954 min
#
# Iteration  3
# train size:  139  test size:  2
# distance: 9796.8, elevation: 140.224, time: 41.3666666667
# distance: 9982.2, elevation: 93.5022, time: 40.8166666667
# Train set evaluation
# Mean Squared Error: 31.2526 min
# ...

# %% [markdown]
# Predictions:

# %%
# %run raceTimePredictor.py
# Out:
# Load Data
# train size:  141  test size:  11
# Start training
#
# Train set evaluation
# Mean Squared Error: 57.3529 min
# Root Mean Squared Error: 6.98754 min
#
# Test set evaluation
# Mean Squared Error: 70.4827 min
# Root Mean Squared Error: 8.26333 min
#
#
# Predictions
#
#      dist  elev  hilly   cs  atl  ctl  isRace  avgVo2max   time
# 0    5000     0    0.0  0.0   30   45       1  37.981768   17.5
# 1    5000    70    0.1  0.2   30   45       1  37.981768   19.0
# 2    5000   150    0.3  1.5   30   45       1  37.981768   22.0
# 3   10000     0    0.0  0.0   30   45       1  37.981768   36.5
# 4   10000    70    0.3  0.5   30   45       1  37.981768   39.0
# 5   10000   150    0.5  1.5   30   45       1  37.981768   41.0
# 6   21097     0    0.0  0.0   30   45       1  37.981768   79.0
# 7   21097    70    0.3  0.5   30   45       1  37.981768   81.0
# 8   21097   150    0.4  1.5   30   50       1  37.981768   85.0
# ...

# %% [markdown]
# With Pre-Training: <br>
# Pre-Train set = all activities of athletes, Train set = kmeans, Evaluation = 4-fold cross validation on train set

# %%
# %run raceTimePredictor.py
# Out:
# Pre-train Set
# train size:  5120
# Train kmeans
#
# Iteration  1
# train size:  139  test size:  2
# distance: 5083.2, elevation: 3.9973, time: 20.1166666667
# distance: 9989.7, elevation: 35.8716, time: 42.0666666667
# Train set evaluation
# Mean Squared Error: 27.1579 min
# Root Mean Squared Error: 6.51843 min
#
# Test set evaluation
# Mean Squared Error: 6.75337 min
# Root Mean Squared Error: 1.80937 min
#
# Iteration  2
# train size:  139  test size:  2
# distance: 10032.0, elevation: 10.2774, time: 42.5666666667
# distance: 21049.6, elevation: 57.7658, time: 91.2333333333
# Train set evaluation
# Mean Squared Error: 27.4139 min
# Root Mean Squared Error: 6.53798 min
#
# Test set evaluation
# Mean Squared Error: 5.85439 min
# Root Mean Squared Error: 1.52814 min
#
# Iteration  3
# train size:  139  test size:  2
# distance: 9796.8, elevation: 140.224, time: 41.3666666667
# distance: 9982.2, elevation: 93.5022, time: 40.8166666667
# Train set evaluation
# ...

# %% [markdown]
# <b style='font-size: 13pt'>DI RK: <br></b>
# Train set = kmeans, Evaluation = 4-fold cross validation

# %%
# %run raceTimePredictor.py
# Out:
# Load Data
# Start training
#
# Iteration  1
# train size:  114  test size:  6
# distance: 5014.3, elevation: 41.2764, time: 20.9333333333
# distance: 7965.8, elevation: 184.471, time: 35.7
# distance: 4871.5, elevation: 68.2267, time: 19.1166666667
# distance: 9530.4, elevation: 156.777, time: 41.25
# distance: 9574.5, elevation: 28.7771, time: 40.4333333333
# distance: 9966.9, elevation: 164.48, time: 51.7333333333
# Train set evaluation
# Mean Squared Error: 9.18717 min
# Root Mean Squared Error: 2.8821 min
#
# Test set evaluation
# Mean Squared Error: 9.04584 min
# Root Mean Squared Error: 2.85748 min
#
# Iteration  2
# train size:  114  test size:  6
# distance: 9999.6, elevation: 11.9067, time: 45.4166666667
# distance: 16404.9, elevation: 361.209, time: 88.45
# distance: 8145.7, elevation: 329.967, time: 44.0
# distance: 9818.8, elevation: 437.801, time: 53.9333333333
# distance: 5020.7, elevation: 43.325, time: 19.75
# distance: 9649.9, elevation: 40.0708, time: 41.6166666667
# ...

# %% [markdown]
# Predictions:

# %%
# %run raceTimePredictor.py
# Out:
# Load Data
# train size:  120  test size:  11
# Start training
#
# Train set evaluation
# Mean Squared Error: 9.03782 min
# Root Mean Squared Error: 2.85678 min
#
# Test set evaluation
# Mean Squared Error: 90.0872 min
# Root Mean Squared Error: 9.44514 min
#
#
# Predictions
#
#      dist  elev  hilly   cs  atl  ctl  isRace  avgVo2max   time
# 0    5000     0    0.0  0.0   30   45       1   35.20302   17.5
# 1    5000    70    0.1  0.2   30   45       1   35.20302   19.0
# 2    5000   150    0.3  1.5   30   45       1   35.20302   22.0
# 3   10000     0    0.0  0.0   30   45       1   35.20302   36.5
# 4   10000    70    0.3  0.5   30   45       1   35.20302   39.0
# 5   10000   150    0.5  1.5   30   45       1   35.20302   41.0
# 6   21097     0    0.0  0.0   30   45       1   35.20302   79.0
# 7   21097    70    0.3  0.5   30   45       1   35.20302   81.0
# 8   21097   150    0.4  1.5   30   50       1   35.20302   85.0
# ...

# %% [markdown]
# With Pre-Training: <br>
# Pre-Train set = all activities of athletes, Train set = kmeans, Evaluation = 4-fold cross validation on train set

# %%
# %run raceTimePredictor.py
# Out:
# Pre-train Set
# train size:  5121
# Train kmeans
#
# Iteration  1
# train size:  114  test size:  6
# distance: 5014.3, elevation: 41.2764, time: 20.9333333333
# distance: 7965.8, elevation: 184.471, time: 35.7
# distance: 4871.5, elevation: 68.2267, time: 19.1166666667
# distance: 9530.4, elevation: 156.777, time: 41.25
# distance: 9574.5, elevation: 28.7771, time: 40.4333333333
# distance: 9966.9, elevation: 164.48, time: 51.7333333333
# Train set evaluation
# Mean Squared Error: 9.56048 min
# Root Mean Squared Error: 2.90723 min
#
# Test set evaluation
# Mean Squared Error: 8.99918 min
# Root Mean Squared Error: 2.80904 min
#
# Iteration  2
# train size:  114  test size:  6
# distance: 9999.6, elevation: 11.9067, time: 45.4166666667
# distance: 16404.9, elevation: 361.209, time: 88.45
# distance: 8145.7, elevation: 329.967, time: 44.0
# distance: 9818.8, elevation: 437.801, time: 53.9333333333
# distance: 5020.7, elevation: 43.325, time: 19.75
# ...
