# %% [markdown]
# Usage of the complete activity set to find correlations betweens values

# %%
# %load plotActivitySet.py
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
from sklearn import preprocessing
import math as math



def plotSet():
	data = pd.read_csv('../output/activitieSetRelation.csv')
	print('samples: ',len(data))
	colors = ['red', 'blue', 'green', 'yellow', 'cyan', 'grey', 'purple', 'coral', 'k', 'saddlebrown']
	
	
	fig = plt.figure(figsize=(12, 4), dpi=100, facecolor='w')
	ax = fig.add_subplot(111, projection='3d')

	
	
	ax.scatter(data['distance'], data['elevation'], data['time'], c='r', s=2)


	plt.legend(fontsize="small", loc="upper right")
	ax.set_xlabel('distance')
	ax.set_ylabel('elevation')
	ax.set_zlabel('time')
	plt.grid()
	plt.show()

	

def plotElevSpeed():
	data = pd.read_csv('../output/activitieSetRelation.csv')
	print('samples: ',len(data))
	plt.figure(figsize=(12, 4), dpi=100, facecolor='w')
	for i in range(8, 80):
		filtered = data[(data.distance > i * 500 - 250) & (data.distance < i * 500 + 250)]
		if len(filtered > 0):
			std_scale = preprocessing.StandardScaler().fit(filtered)
			filtered = std_scale.transform(filtered)
			plt.scatter(filtered[:, 1], filtered[:, 2], c='grey', s=2, label='')
	plt.xlabel('elevation')
	plt.ylabel('time')
	plt.legend()
	plt.grid()
	plt.show()

def plotXWWeeklyMileage():
	data = pd.read_csv('../output/activitieSetRelation.csv')
	print('samples: ',len(data))
	plt.figure(figsize=(12, 4), dpi=100, facecolor='w')
	# data = data[data.isRace == 1]
			
	plt.scatter(data['XWWeeklyMileage'] / 1000, data['ngp'], c='r', s=2)
	
	plt.legend(fontsize="small", loc="upper right")
	plt.grid()
	plt.xlabel('weeklyMileage')
	plt.ylabel('NGP')

	plt.show()

def plotXWElevation():
	data = pd.read_csv('../output/activitieSetRelation.csv')
	print('samples: ',len(data))
	plt.figure(figsize=(12, 4), dpi=100, facecolor='w')
	for i in range(0, 30):
		filtered = data[(data.elevation > i * 50 - 25) & (data.elevation < i * 50 + 25)]
		if len(filtered > 0):
			std_scale = preprocessing.StandardScaler().fit(filtered)
			filtered = std_scale.transform(filtered)
			plt.scatter(filtered[:, 3], filtered[:, -1], c='grey', s=2, label='')
	
			
	
	plt.legend(fontsize="small", loc="upper right")
	plt.grid()
	plt.xlabel('Elevation gain')
	plt.ylabel('NGP')

	plt.show()

def plotXWSpeedwork():
	data = pd.read_csv('../output/activitieSetRelation.csv')
	print('samples: ',len(data))
	plt.figure(figsize=(12, 4), dpi=100, facecolor='w')
	data = data[data.isRace == 1]
			
	plt.scatter(data['speedwork'], data['ngp'], c='r', s=2)
	
	plt.legend(fontsize="small", loc="upper right")
	plt.grid()
	plt.xlabel('number speedwork')
	plt.ylabel('NGP')

	plt.show()

def plotXWLongRuns():
	data = pd.read_csv('../output/activitieSetRelation.csv')
	print('samples: ',len(data))
	plt.figure(figsize=(12, 4), dpi=100, facecolor='w')
	data = data[data.distance > 9500]
	# data = data[data.isRace == 1]


			
	for i in range(18, 80):
		filtered = data[(data.distance > i * 1000 - 500) & (data.distance < i * 1000 + 500)]
		if len(filtered > 0):
			std_scale = preprocessing.StandardScaler().fit(filtered[['time']])
			filtered[['time']] = std_scale.transform(filtered[['time']])
			plt.scatter(filtered['long'], filtered['time'], c='grey', s=2, label='')
	
	plt.legend(fontsize="small", loc="upper right")
	plt.grid()
	plt.xlabel('number long runs')
	plt.ylabel('time')

	plt.show()

# plotXWWeeklyMileage()
# plotElevSpeed()
# plotXWElevation()
# plotXWSpeedwork()
plotXWLongRuns()

# plotSet()

# %% [markdown]
# Set with basic filtering

# %%
# %run plotActivitySet.py
# Out:
# samples:  1750

# %% [markdown]
# Set without speedwork, longer than 4.5 km and  faster than 6:30 min/km. Data is divided in 500 m blocks and standardized to remove the distance factor

# %%
# %run plotActivitySet.py
# Out:
# samples:  1114

# %% [markdown]
# Set without speedwork, longer than 4.5 km and  faster than 6:30 min/km. 8 weeks weekly mileage against NGP

# %%
# %run plotActivitySet.py
# Out:
# samples:  1114

# %% [markdown]
# Set without speedwork, longer than 4.5 km and faster than 6:30 min/km. Data is divided in 50 m elevation blocks and standardized to remove the elevation factor. 8 weeks average elevation gain against NGP

# %%
# %run plotActivitySet.py
# Out:
# samples:  1114

# %% [markdown]
# Set with races only, longer than 4.5 km and faster than 6:30 min/km. 8 weeks number of speedwork against NGP

# %%
# %run plotActivitySet.py
# Out:
# samples:  1114

# %% [markdown]
# Set without speedwork, longer than 9.5 km and  faster than 6:30 min/km. Data is divided in 1000 m distance blocks and standardized to remove the distance factor. 8 weeks number of long runs against NGP.

# %%
# %run plotActivitySet.py
# Out:
# samples:  1114
# C:\Users\Juls\Desktop\Prediction Server\data\python\plotActivitySet.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\program files\python36\lib\site-packages\pandas\core\indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %% [markdown]
# Set without speedwork, longer than 4.5 km and faster than 6:30 min/km. 8 weeks average training pace against NGP.

# %%
# %run plotActivitySet.py
# Out:
# samples:  1266

# %% [markdown]
# Set with races only, longer than 4.5 km and faster than 6:30 min/km. 8 weeks average training pace against NGP

# %%
# %run plotActivitySet.py
# Out:
# samples:  73

# %% [markdown]
# Set without speedwork, longer than 4.5 km and faster than 6:30 min/km. 8 weeks average Vo2Max against NGP.

# %%
# %run plotActivitySet.py
# Out:
# samples:  1266

# %% [markdown]
# Set with races only, longer than 4.5 km and faster than 6:30 min/km. 8 weeks average Vo2Max against NGP.

# %%
# %run plotActivitySet.py
# Out:
# samples:  73
