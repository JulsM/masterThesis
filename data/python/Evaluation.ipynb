# %% [markdown]
# <strong>Activity based</strong>

# %%
# %run racetimePredictor.py
# Out:
# Athlete  Florian Daiber
# Start training
#
# Iteration  1
# train size:  217  test size:  3
# dist: 42.24 km, elev: 133.51 m, time: 209.72 min, predicted time: 194.75 min, accuracy: 92.86 %
# dist: 5.03 km, elev: 3.86 m, time: 18.93 min, predicted time: 20.93 min, accuracy: 89.46 %
# dist: 30.74 km, elev: 768.46 m, time: 179.03 min, predicted time: 158.70 min, accuracy: 88.64 %
# Test set evaluation
# Mean Squared Error: 213.7331 min
# Mean Absolute Error: 12.4295 min
# Root Mean Squared Error: 14.6196 min
# Accuracy: 90.32 %
#
# Iteration  2
# train size:  216  test size:  4
# dist: 9.07 km, elev: 407.77 m, time: 42.62 min, predicted time: 56.98 min, accuracy: 66.30 %
# dist: 9.89 km, elev: 150.72 m, time: 39.38 min, predicted time: 54.42 min, accuracy: 61.81 %
# dist: 30.60 km, elev: 780.83 m, time: 172.27 min, predicted time: 170.01 min, accuracy: 98.69 %
# dist: 9.81 km, elev: 154.52 m, time: 38.92 min, predicted time: 58.28 min, accuracy: 50.25 %
# Test set evaluation
# ...

# %%
# %run plotEvaluation.py
