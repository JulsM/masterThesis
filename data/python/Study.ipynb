# %% [markdown]
# Julian Maurer

# %%
# %run raceTimePredictor.py
# Out:
# Load Data
# train size:  79
# Start training
#
# Test set evaluation
# Mean Squared Error: 10.1830 min
# Mean Absolute Error: 3.1911 min
# Root Mean Squared Error: 3.1911 min
# Accuracy: 91.82 %
#
#
# Predictions
#
#      dist    elev  hilly    cs      atl      ctl  isRace  avgVo2max  time
# 0  9931.1  147.38   0.49  1.08  49.9592  49.9426       1  41.565232    39
# Predicted time 0: 42.19 min
# +/- Seconds: 191.47, Accuracy: 91.82 %

# %% [markdown]
# Lauflinchen

# %%
# %run raceTimePredictor.py
# Out:
# Load Data
# train size:  85
# Start training
#
# Test set evaluation
# Mean Squared Error: 5.5200 min
# Mean Absolute Error: 2.3495 min
# Root Mean Squared Error: 2.3495 min
# Accuracy: 95.64 %
#
#
# Predictions
#
#      dist     elev  hilly    cs      atl      ctl  isRace  avgVo2max  time
# 0  9815.1  134.384   0.58  1.39  72.6423  70.4646       1  32.425255  53.9
# Predicted time 0: 51.55 min
# +/- Seconds: -140.97, Accuracy: 95.64 %

# %% [markdown]
# Kai K

# %%
# %run raceTimePredictor.py
# Out:
# Load Data
# train size:  109
# Start training
#
# Test set evaluation
# Mean Squared Error: 14.9602 min
# Mean Absolute Error: 3.8678 min
# Root Mean Squared Error: 3.8678 min
# Accuracy: 90.74 %
#
#
# Predictions
#
#      dist     elev  hilly    cs      atl      ctl  isRace  avgVo2max  \
# 0  9933.1  141.543   0.58  0.81  15.1136  17.7648       1   32.35328
#
#         time
# 0  41.766667
# Predicted time 0: 45.63 min
# +/- Seconds: 232.07, Accuracy: 90.74 %

# %% [markdown]
# Martin Mühlhan

# %%
# %run raceTimePredictor.py
# Out:
# Load Data
# Start training
#
# Test set evaluation
# Mean Squared Error: 0.1662 min
# Mean Absolute Error: 0.4077 min
# Root Mean Squared Error: 0.4077 min
# Accuracy: 98.96 %
#
#
# Predictions
#
#      dist     elev  hilly    cs      atl      ctl  isRace  avgVo2max  time
# 0  9934.9  141.489   0.65  0.92  39.1022  45.3254       1  46.752558  39.3
# Predicted time 0: 39.71 min
# +/- Seconds: 24.46, Accuracy: 98.96 %

# %% [markdown]
# Monika Paul

# %%
# %run raceTimePredictor.py
# Out:
# Load Data
# Start training
#
# Test set evaluation
# Mean Squared Error: 74.8848 min
# Mean Absolute Error: 8.6536 min
# Root Mean Squared Error: 8.6536 min
# Accuracy: 82.86 %
#
#
# Predictions
#
#       dist     elev  hilly    cs      atl      ctl  isRace  avgVo2max  time
# 0  10116.5  139.801   0.53  1.15  37.4182  31.8973       1  36.332936  50.5
# Predicted time 0: 59.15 min
# +/- Seconds: 519.22, Accuracy: 82.86 %

# %% [markdown]
# Chris WA

# %%
# %run raceTimePredictor.py
# Out:
# Load Data
# Start training
#
# Test set evaluation
# Mean Squared Error: 0.8793 min
# Mean Absolute Error: 0.9377 min
# Root Mean Squared Error: 0.9377 min
# Accuracy: 97.82 %
#
#
# Predictions
#
#       dist     elev  hilly    cs      atl      ctl  isRace  avgVo2max   time
# 0  10036.3  146.142   0.55  1.16  10.6183  10.4556       1   42.17555  42.95
# Predicted time 0: 43.89 min
# +/- Seconds: 56.26, Accuracy: 97.82 %

# %% [markdown]
# Kai Detemple

# %%
# %run raceTimePredictor.py
# Out:
# Load Data
# Start training
#
# Test set evaluation
# Mean Squared Error: 0.2054 min
# Mean Absolute Error: 0.4532 min
# Root Mean Squared Error: 0.4532 min
# Accuracy: 99.08 %
#
#
# Predictions
#
#    dist     elev  hilly    cs      atl     ctl  isRace  avgVo2max       time
# 0  9950  140.096   0.64  1.42  31.2583  35.728       1  34.706627  49.266667
# Predicted time 0: 49.72 min
# +/- Seconds: 27.19, Accuracy: 99.08 %

# %% [markdown]
# Alexander Zeiner

# %%
# %run raceTimePredictor.py
# Out:
# Load Data
# train size:  147
# Start training
#
# Test set evaluation
# Mean Squared Error: 1.3235 min
# Mean Absolute Error: 1.1504 min
# Root Mean Squared Error: 1.1504 min
# Accuracy: 97.15 %
#
#
# Predictions
#
#      dist     elev  hilly    cs      atl      ctl  isRace  avgVo2max  \
# 0  9755.7  135.057   0.51  1.16  41.3069  33.9689       1  42.349975
#
#         time
# 0  40.433333
# Predicted time 0: 39.28 min
# +/- Seconds: -69.03, Accuracy: 97.15 %

# %% [markdown]
# Martin B.

# %%
# %run raceTimePredictor.py
# Out:
# Load Data
# Start training
#
# Test set evaluation
# Mean Squared Error: 0.6840 min
# Mean Absolute Error: 0.8270 min
# Root Mean Squared Error: 0.8270 min
# Accuracy: 97.91 %
#
#
# Predictions
#
#      dist     elev  hilly    cs      atl      ctl  isRace  avgVo2max  time
# 0  9851.7  138.949   0.54  0.73  15.8281  15.0865       1  41.889367  39.5
# Predicted time 0: 40.33 min
# +/- Seconds: 49.62, Accuracy: 97.91 %

# %% [markdown]
# Peter Petto

# %%
# %run raceTimePredictor.py
# Out:
# Load Data
# Start training
#
# Test set evaluation
# Mean Squared Error: 101.1151 min
# Mean Absolute Error: 10.0556 min
# Root Mean Squared Error: 10.0556 min
# Accuracy: 75.93 %
#
#
# Predictions
#
#      dist     elev  hilly  cs      atl      ctl  isRace  avgVo2max       time
# 0  9948.5  133.484   0.43   1  28.0646  43.7863       1  33.904857  41.783333
# Predicted time 0: 51.84 min
# +/- Seconds: 603.34, Accuracy: 75.93 %

# %% [markdown]
# Conny Ziegler

# %%
# %run raceTimePredictor.py
# Out:
# Load Data
# train size:  80
# Start training
#
# Test set evaluation
# Mean Squared Error: 1.5238 min
# Mean Absolute Error: 1.2344 min
# Root Mean Squared Error: 1.2344 min
# Accuracy: 97.52 %
#
#
# Predictions
#
#    dist     elev  hilly    cs      atl      ctl  isRace  avgVo2max  time
# 0  9847  145.566   0.61  1.55  43.5171  44.9862       1  34.061415  49.8
# Predicted time 0: 51.03 min
# +/- Seconds: 74.07, Accuracy: 97.52 %

# %% [markdown]
# Florian Daiber

# %%
# %run raceTimePredictor.py
# Out:
# Load Data
# train size:  204
# Start training
#
# Test set evaluation
# Mean Squared Error: 36.3115 min
# Mean Absolute Error: 6.0259 min
# Root Mean Squared Error: 6.0259 min
# Accuracy: 84.52 %
#
#
# Predictions
#
#      dist     elev  hilly    cs      atl      ctl  isRace  avgVo2max  \
# 0  9808.8  154.516   0.64  1.35  33.6232  57.8493       1  32.546497
#
#         time
# 0  38.916667
# Predicted time 0: 44.94 min
# +/- Seconds: 361.55, Accuracy: 84.52 %

# %% [markdown]
# Segments

# %% [markdown]
# Julian Maurer

# %%
# %run segmentPredictor.py
# Out:
# train size:  1667  test size:  25
# Start training
#
# Test set evaluation
# Mean Squared Error: 63.9709 sec
# Mean Absolute Error: 6.19135 sec
# Root Mean Squared Error: 7.99818 sec
# Accuracy: 91.65 %
#
#
# Predictions
#
# Predicted time 0: 73.34 sec, offset: -3.66 sec, Vel: 4:6 min/km, Sim: 95.25 %
# Predicted time 1: 89.55 sec, offset: 3.55 sec, Vel: 4:9 min/km, Sim: 95.87 %
# Predicted time 2: 184.28 sec, offset: 16.28 sec, Vel: 4:3 min/km, Sim: 90.31 %
# Predicted time 3: 50.28 sec, offset: 9.28 sec, Vel: 4:19 min/km, Sim: 77.37 %
# Predicted time 4: 68.47 sec, offset: 2.47 sec, Vel: 4:37 min/km, Sim: 96.26 %
# Predicted time 5: 80.0 sec, offset: 5.0 sec, Vel: 4:10 min/km, Sim: 93.33 %
# Predicted time 6: 82.19 sec, offset: -5.81 sec, Vel: 3:59 min/km, Sim: 93.4 %
# Predicted time 7: 80.02 sec, offset: -5.98 sec, Vel: 4:6 min/km, Sim: 93.05 %
# Predicted time 8: 76.14 sec, offset: -1.86 sec, Vel: 4:13 min/km, Sim: 97.62 %
# ...

# %%
# %run plotSegmentResults.py

# %% [markdown]
# Lauflinchen

# %%
# %run segmentPredictor.py
# Out:
# train size:  1375  test size:  20
# Start training
#
# Test set evaluation
# Mean Squared Error: 309.202 sec
# Mean Absolute Error: 12.8737 sec
# Root Mean Squared Error: 17.5841 sec
# Accuracy: 90.06 %
#
#
# Predictions
#
# Predicted time 0: 89.78 sec, offset: 1.78 sec, Vel: 5:16 min/km, Sim: 97.97 %
# Predicted time 1: 120.05 sec, offset: 1.05 sec, Vel: 5:28 min/km, Sim: 99.12 %
# Predicted time 2: 256.02 sec, offset: 34.02 sec, Vel: 5:37 min/km, Sim: 84.67 %
# Predicted time 3: 208.25 sec, offset: -1.75 sec, Vel: 5:43 min/km, Sim: 99.17 %
# Predicted time 4: 47.19 sec, offset: -15.81 sec, Vel: 4:19 min/km, Sim: 74.9 %
# Predicted time 5: 154.45 sec, offset: -8.55 sec, Vel: 5:33 min/km, Sim: 94.75 %
# Predicted time 6: 140.28 sec, offset: -17.72 sec, Vel: 5:16 min/km, Sim: 88.78 %
# Predicted time 7: 399.92 sec, offset: 33.92 sec, Vel: 5:36 min/km, Sim: 90.73 %
# Predicted time 8: 267.68 sec, offset: 1.68 sec, Vel: 5:34 min/km, Sim: 99.37 %
# ...

# %%
# %run plotSegmentResults.py

# %% [markdown]
# Kai K

# %%
# %run segmentPredictor.py
# Out:
# train size:  1112  test size:  24
# Start training
#
# Test set evaluation
# Mean Squared Error: 259.078 sec
# Mean Absolute Error: 12.8366 sec
# Root Mean Squared Error: 16.0959 sec
# Accuracy: 82.75 %
#
#
# Predictions
#
# Predicted time 0: 66.7 sec, offset: -11.3 sec, Vel: 4:3 min/km, Sim: 85.52 %
# Predicted time 1: 88.08 sec, offset: -12.92 sec, Vel: 3:55 min/km, Sim: 87.21 %
# Predicted time 2: 179.49 sec, offset: -1.51 sec, Vel: 3:54 min/km, Sim: 99.16 %
# Predicted time 3: 74.79 sec, offset: -28.21 sec, Vel: 3:34 min/km, Sim: 72.61 %
# Predicted time 4: 79.26 sec, offset: -7.74 sec, Vel: 3:57 min/km, Sim: 91.11 %
# Predicted time 5: 238.16 sec, offset: -45.84 sec, Vel: 3:49 min/km, Sim: 83.86 %
# Predicted time 6: 283.97 sec, offset: -6.03 sec, Vel: 3:55 min/km, Sim: 97.92 %
# Predicted time 7: 62.0 sec, offset: -9.0 sec, Vel: 4:11 min/km, Sim: 87.32 %
# Predicted time 8: 74.11 sec, offset: -8.89 sec, Vel: 3:53 min/km, Sim: 89.29 %
# ...

# %%
# %run plotSegmentResults.py

# %% [markdown]
# Martin Mühlhan

# %%
# %run segmentPredictor.py
# Out:
# train size:  2349  test size:  27
# Start training
#
# Test set evaluation
# Mean Squared Error: 52.9346 sec
# Mean Absolute Error: 5.37939 sec
# Root Mean Squared Error: 7.27561 sec
# Accuracy: 92.70 %
#
#
# Predictions
#
# Predicted time 0: 77.63 sec, offset: 6.63 sec, Vel: 4:17 min/km, Sim: 90.66 %
# Predicted time 1: 89.32 sec, offset: 7.32 sec, Vel: 4:19 min/km, Sim: 91.07 %
# Predicted time 2: 186.7 sec, offset: 23.7 sec, Vel: 4:5 min/km, Sim: 85.46 %
# Predicted time 3: 94.33 sec, offset: 2.33 sec, Vel: 4:33 min/km, Sim: 97.47 %
# Predicted time 4: 85.09 sec, offset: 7.09 sec, Vel: 4:18 min/km, Sim: 90.91 %
# Predicted time 5: 55.92 sec, offset: 1.92 sec, Vel: 4:36 min/km, Sim: 96.44 %
# Predicted time 6: 54.54 sec, offset: -4.46 sec, Vel: 3:58 min/km, Sim: 92.43 %
# Predicted time 7: 66.37 sec, offset: 3.37 sec, Vel: 4:28 min/km, Sim: 94.66 %
# Predicted time 8: 58.57 sec, offset: -4.43 sec, Vel: 4:11 min/km, Sim: 92.96 %
# ...

# %%
# %run plotSegmentResults.py

# %% [markdown]
# Monika Paul

# %%
# %run segmentPredictor.py
# Out:
# train size:  205  test size:  29
# Start training
#
# Test set evaluation
# Mean Squared Error: 201.151 sec
# Mean Absolute Error: 11.0981 sec
# Root Mean Squared Error: 14.1828 sec
# Accuracy: 87.92 %
#
#
# Predictions
#
# Predicted time 0: 97.81 sec, offset: 20.81 sec, Vel: 5:41 min/km, Sim: 72.98 %
# Predicted time 1: 121.4 sec, offset: 11.4 sec, Vel: 5:34 min/km, Sim: 89.64 %
# Predicted time 2: 249.34 sec, offset: 22.34 sec, Vel: 5:21 min/km, Sim: 90.16 %
# Predicted time 3: 95.52 sec, offset: 6.52 sec, Vel: 5:44 min/km, Sim: 92.67 %
# Predicted time 4: 78.27 sec, offset: 11.27 sec, Vel: 6:9 min/km, Sim: 83.17 %
# Predicted time 5: 80.09 sec, offset: 9.09 sec, Vel: 5:43 min/km, Sim: 87.19 %
# Predicted time 6: 97.45 sec, offset: 3.45 sec, Vel: 5:35 min/km, Sim: 96.33 %
# Predicted time 7: 96.82 sec, offset: 0.82 sec, Vel: 5:30 min/km, Sim: 99.15 %
# Predicted time 8: 141.55 sec, offset: -9.45 sec, Vel: 5:15 min/km, Sim: 93.74 %
# ...

# %%
# %run plotSegmentResults.py

# %% [markdown]
# Chris WA

# %%
# %run segmentPredictor.py
# Out:
# train size:  788  test size:  31
# Start training
#
# Test set evaluation
# Mean Squared Error: 113.098 sec
# Mean Absolute Error: 8.86233 sec
# Root Mean Squared Error: 10.6348 sec
# Accuracy: 87.28 %
#
#
# Predictions
#
# Predicted time 0: 68.14 sec, offset: -9.86 sec, Vel: 3:38 min/km, Sim: 87.36 %
# Predicted time 1: 82.43 sec, offset: -16.57 sec, Vel: 3:48 min/km, Sim: 83.26 %
# Predicted time 2: 185.99 sec, offset: -12.01 sec, Vel: 4:2 min/km, Sim: 93.93 %
# Predicted time 3: 57.52 sec, offset: -20.48 sec, Vel: 3:44 min/km, Sim: 73.74 %
# Predicted time 4: 90.09 sec, offset: -6.91 sec, Vel: 4:7 min/km, Sim: 92.88 %
# Predicted time 5: 56.9 sec, offset: -16.1 sec, Vel: 3:47 min/km, Sim: 77.94 %
# Predicted time 6: 45.73 sec, offset: -21.27 sec, Vel: 3:20 min/km, Sim: 68.25 %
# Predicted time 7: 61.9 sec, offset: -12.1 sec, Vel: 3:51 min/km, Sim: 83.65 %
# Predicted time 8: 46.71 sec, offset: -19.29 sec, Vel: 3:33 min/km, Sim: 70.78 %
# ...

# %%
# %run plotSegmentResults.py

# %% [markdown]
# Kai Detemple

# %%
# %run segmentPredictor.py
# Out:
# train size:  1364  test size:  25
# Start training
#
# Test set evaluation
# Mean Squared Error: 1501.04 sec
# Mean Absolute Error: 30.4707 sec
# Root Mean Squared Error: 38.7432 sec
# Accuracy: 77.12 %
#
#
# Predictions
#
# Predicted time 0: 68.51 sec, offset: -10.49 sec, Vel: 4:0 min/km, Sim: 86.72 %
# Predicted time 1: 83.88 sec, offset: -22.12 sec, Vel: 3:47 min/km, Sim: 79.13 %
# Predicted time 2: 158.77 sec, offset: -54.23 sec, Vel: 3:26 min/km, Sim: 74.54 %
# Predicted time 3: 154.05 sec, offset: -78.95 sec, Vel: 3:26 min/km, Sim: 66.12 %
# Predicted time 4: 44.27 sec, offset: -7.73 sec, Vel: 4:42 min/km, Sim: 85.13 %
# Predicted time 5: 169.4 sec, offset: -100.6 sec, Vel: 3:25 min/km, Sim: 62.74 %
# Predicted time 6: 42.64 sec, offset: -3.36 sec, Vel: 4:41 min/km, Sim: 92.7 %
# Predicted time 7: 83.42 sec, offset: -17.58 sec, Vel: 3:43 min/km, Sim: 82.59 %
# Predicted time 8: 167.76 sec, offset: -58.24 sec, Vel: 3:25 min/km, Sim: 74.23 %
# ...

# %%
# %run plotSegmentResults.py

# %% [markdown]
# Alexander Zeiner

# %%
# %run segmentPredictor.py
# Out:
# train size:  1273  test size:  23
# Start training
#
# Test set evaluation
# Mean Squared Error: 96.8644 sec
# Mean Absolute Error: 8.45113 sec
# Root Mean Squared Error: 9.84197 sec
# Accuracy: 87.96 %
#
#
# Predictions
#
# Predicted time 0: 64.53 sec, offset: -2.47 sec, Vel: 3:51 min/km, Sim: 96.31 %
# Predicted time 1: 91.6 sec, offset: -5.4 sec, Vel: 4:5 min/km, Sim: 94.44 %
# Predicted time 2: 190.13 sec, offset: 15.13 sec, Vel: 4:17 min/km, Sim: 91.35 %
# Predicted time 3: 198.29 sec, offset: 2.29 sec, Vel: 4:23 min/km, Sim: 98.83 %
# Predicted time 4: 79.9 sec, offset: -16.1 sec, Vel: 3:48 min/km, Sim: 83.23 %
# Predicted time 5: 160.72 sec, offset: -8.28 sec, Vel: 4:15 min/km, Sim: 95.1 %
# Predicted time 6: 42.5 sec, offset: -8.5 sec, Vel: 3:10 min/km, Sim: 83.32 %
# Predicted time 7: 38.18 sec, offset: -11.82 sec, Vel: 2:54 min/km, Sim: 76.36 %
# Predicted time 8: 163.66 sec, offset: 4.66 sec, Vel: 4:5 min/km, Sim: 97.07 %
# ...

# %%
# %run plotSegmentResults.py

# %% [markdown]
# Martin B.

# %%
# %run segmentPredictor.py
# Out:
# train size:  759  test size:  31
# Start training
#
# Test set evaluation
# Mean Squared Error: 2559.44 sec
# Mean Absolute Error: 37.6732 sec
# Root Mean Squared Error: 50.5909 sec
# Accuracy: 41.50 %
#
#
# Predictions
#
# Predicted time 0: -30.84 sec, offset: -92.84 sec, Vel: -1:13 min/km, Sim: -49.74 %
# Predicted time 1: -16.33 sec, offset: -99.33 sec, Vel: 0:15 min/km, Sim: -19.68 %
# Predicted time 2: 9.71 sec, offset: -55.29 sec, Vel: 0:33 min/km, Sim: 14.94 %
# Predicted time 3: 0.49 sec, offset: -59.51 sec, Vel: 0:1 min/km, Sim: 0.81 %
# Predicted time 4: 14.92 sec, offset: -36.08 sec, Vel: 1:3 min/km, Sim: 29.25 %
# Predicted time 5: 21.69 sec, offset: -32.31 sec, Vel: 1:42 min/km, Sim: 40.17 %
# Predicted time 6: 28.28 sec, offset: -63.72 sec, Vel: 1:16 min/km, Sim: 30.74 %
# Predicted time 7: 74.19 sec, offset: 22.19 sec, Vel: 6:11 min/km, Sim: 57.33 %
# Predicted time 8: 75.82 sec, offset: 8.82 sec, Vel: 4:37 min/km, Sim: 86.83 %
# ...

# %%
# %run plotSegmentResults.py

# %% [markdown]
# Peter Petto

# %%
# %run segmentPredictor.py
# Out:
# train size:  918  test size:  20
# Start training
#
# Test set evaluation
# Mean Squared Error: 6194.88 sec
# Mean Absolute Error: 57.2858 sec
# Root Mean Squared Error: 78.7076 sec
# Accuracy: 61.54 %
#
#
# Predictions
#
# Predicted time 0: 506.9 sec, offset: 149.9 sec, Vel: 5:59 min/km, Sim: 58.01 %
# Predicted time 1: 351.11 sec, offset: 167.11 sec, Vel: 8:22 min/km, Sim: 9.18 %
# Predicted time 2: 143.08 sec, offset: 31.08 sec, Vel: 5:41 min/km, Sim: 72.25 %
# Predicted time 3: 121.19 sec, offset: 38.19 sec, Vel: 6:44 min/km, Sim: 53.99 %
# Predicted time 4: 106.72 sec, offset: 22.72 sec, Vel: 5:59 min/km, Sim: 72.96 %
# Predicted time 5: 368.76 sec, offset: 128.76 sec, Vel: 5:52 min/km, Sim: 46.35 %
# Predicted time 6: 139.57 sec, offset: 46.57 sec, Vel: 5:38 min/km, Sim: 49.93 %
# Predicted time 7: 50.61 sec, offset: 1.61 sec, Vel: 4:30 min/km, Sim: 96.71 %
# Predicted time 8: 160.67 sec, offset: 49.67 sec, Vel: 6:15 min/km, Sim: 55.25 %
# ...

# %%
# %run plotSegmentResults.py

# %% [markdown]
# Conny Ziegler

# %%
# %run segmentPredictor.py
# Out:
# train size:  1849  test size:  26
# Start training
#
# Test set evaluation
# Mean Squared Error: 114.779 sec
# Mean Absolute Error: 8.92848 sec
# Root Mean Squared Error: 10.7135 sec
# Accuracy: 91.43 %
#
#
# Predictions
#
# Predicted time 0: 95.91 sec, offset: 6.91 sec, Vel: 5:26 min/km, Sim: 92.24 %
# Predicted time 1: 123.47 sec, offset: 10.47 sec, Vel: 5:34 min/km, Sim: 90.74 %
# Predicted time 2: 226.11 sec, offset: 11.11 sec, Vel: 4:58 min/km, Sim: 94.83 %
# Predicted time 3: 204.82 sec, offset: 11.82 sec, Vel: 5:44 min/km, Sim: 93.88 %
# Predicted time 4: 56.07 sec, offset: -5.93 sec, Vel: 5:10 min/km, Sim: 90.43 %
# Predicted time 5: 295.11 sec, offset: -5.89 sec, Vel: 5:23 min/km, Sim: 98.04 %
# Predicted time 6: 129.27 sec, offset: 9.27 sec, Vel: 5:22 min/km, Sim: 92.27 %
# Predicted time 7: 64.63 sec, offset: 2.63 sec, Vel: 5:17 min/km, Sim: 95.76 %
# Predicted time 8: 123.59 sec, offset: 6.59 sec, Vel: 5:21 min/km, Sim: 94.37 %
# ...

# %%
# %run plotSegmentResults.py

# %% [markdown]
# Florian Daiber

# %%
# %run segmentPredictor.py
# Out:
# train size:  4860  test size:  29
# Start training
#
# Test set evaluation
# Mean Squared Error: 427.166 sec
# Mean Absolute Error: 11.6204 sec
# Root Mean Squared Error: 20.668 sec
# Accuracy: 86.61 %
#
#
# Predictions
#
# Predicted time 0: 66.71 sec, offset: 4.71 sec, Vel: 3:45 min/km, Sim: 92.4 %
# Predicted time 1: 89.89 sec, offset: 7.89 sec, Vel: 4:9 min/km, Sim: 90.38 %
# Predicted time 2: 201.96 sec, offset: 33.96 sec, Vel: 4:28 min/km, Sim: 79.79 %
# Predicted time 3: 39.55 sec, offset: -4.45 sec, Vel: 3:30 min/km, Sim: 89.89 %
# Predicted time 4: 74.81 sec, offset: -0.19 sec, Vel: 4:27 min/km, Sim: 99.75 %
# Predicted time 5: 48.73 sec, offset: -2.27 sec, Vel: 3:41 min/km, Sim: 95.54 %
# Predicted time 6: 45.03 sec, offset: -1.97 sec, Vel: 4:18 min/km, Sim: 95.81 %
# Predicted time 7: 37.33 sec, offset: -17.67 sec, Vel: 2:46 min/km, Sim: 67.87 %
# Predicted time 8: 60.62 sec, offset: -1.38 sec, Vel: 4:5 min/km, Sim: 97.78 %
# ...

# %%
# %run plotSegmentResults.py

# %% [markdown]
# <strong>Overview of participants</strong>

# %%
# %run plotAthletesStudy.py

# %% [markdown]
# <strong>Races of all participants</strong> distance in km, elevation gain in m, time in min, hillyness in %

# %%
# %run plotAthletesStudy.py
# Out:
# Julian Maurer
#     distance  elevGain  elapsedTime  hilly        date
# 0       5.05         4           17      2  29-06-2017
# 1       5.09        38           18     45  22-06-2017
# 2       5.37        69           20     49  18-06-2017
# 3       8.01       200           32     77  17-04-2017
# 4       9.52       125           37     57  03-06-2017
# 5       9.88        17           37      9  07-05-2017
# 6       9.97         6           37      2  20-05-2017
# 7      10.01        36           40     16  01-10-2017
# 8      10.02        20           36      6  03-12-2017
# 9      10.03        17           38      5  08-10-2017
# 10     10.05        21           36      2  23-09-2017
# 11     10.06        75           39     27  09-12-2017
# 12     10.07        63           38     21  11-06-2017
# 13     10.09         3           38      1  15-08-2017
# 14     10.11        12           37      6  19-08-2017
# 15     10.39        93           41     47  16-09-2017
# ...

# %% [markdown]
# <strong>Relationship between actual time and predicted time in minutes</strong>

# %%
# %run plotAthletesStudy.py

# %% [markdown]
# <strong>Accuracy and error of activity based prediction per athlete</strong>

# %%
# %run plotAthletesStudy.py

# %% [markdown]
# <strong>Accuracy, similarity and RMSE of segment based prediction per athlete</strong>

# %%
# %run plotAthletesStudy.py

# %% [markdown]
# <strong>Accuracy of Riegel's prediction per athlete</strong>

# %%
# %run plotAthletesStudy.py
