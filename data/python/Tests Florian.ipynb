# %% [markdown]
# Races with 4-fold cross validation

# %%
# %run raceTimePredictor.py
# Out:
# Load Data
#
# Start training
#
# Iteration  0
# train size:  5  test size:  1
# Train set evaluation
# Loss: 4.52985
# Root Mean Squared Error: 0.121961
#
# Test set evaluation
# Loss: 178.107
# Root Mean Squared Error: 13.1754
#
# Iteration  1
# train size:  5  test size:  1
# Train set evaluation
# Loss: 4.31643
# Root Mean Squared Error: 0.0800475
#
# Test set evaluation
# Loss: 204.771
# Root Mean Squared Error: 14.1584
#
# Iteration  2
# train size:  5  test size:  1
# Train set evaluation
# Loss: 4.10924
# Root Mean Squared Error: 0.0457088
#
# Test set evaluation
# Loss: 466.316
# Root Mean Squared Error: 21.499
#
# Iteration  3
# train size:  3  test size:  3
# Train set evaluation
# Loss: 4.83052
# Root Mean Squared Error: 0.165098
#
# Test set evaluation
# Loss: 720.102
# Root Mean Squared Error: 26.7451
#
#
# Mean loss for 4-fold cross validation: 392.324
# Mean RMSE for 4-fold cross validation: 18.8945
#
# Predictions
#
#      dist  elev  hilly   cs  atl  ctl  isRace  avgVo2max   time  avgTrainPace
# 0    5000     0    0.0  0.0   30   45       1       43.5   17.5      3.023757
# 1    5000    70    0.1  0.2   30   45       1       43.5   19.0      3.023757
# 2    5000   150    0.3  1.5   30   45       1       43.5   22.0      3.023757
# 3   10000     0    0.0  0.0   30   45       1       43.5   36.5      3.023757
# 4   10000    70    0.3  0.5   30   45       1       43.5   39.0      3.023757
# 5   10000   150    0.5  1.5   30   45       1       43.5   41.0      3.023757
# 6   21097     0    0.0  0.0   30   45       1       43.5   79.0      3.023757
# 7   21097    70    0.3  0.5   30   45       1       43.5   81.0      3.023757
# 8   21097   150    0.4  1.5   30   50       1       43.5   85.0      3.023757
# 9   42195     0    0.0  0.0   30   50       1       43.5  170.0      3.023757
# 10  42195   150    0.5  1.0   30   50       1       43.5  185.0      3.023757
# Predicted time 0: 90.09
# +/- Seconds: 4355.58
# Predicted time 1: 90.1
# +/- Seconds: 4266.04
# Predicted time 2: 90.12
# +/- Seconds: 4086.97
# Predicted time 3: 103.37
# +/- Seconds: 4011.95
# Predicted time 4: 103.38
# +/- Seconds: 3862.89
# Predicted time 5: 103.4
# +/- Seconds: 3743.76
# Predicted time 6: 132.82
# +/- Seconds: 3229.42
# Predicted time 7: 132.84
# +/- Seconds: 3110.36
# Predicted time 8: 153.78
# +/- Seconds: 4126.85
# Predicted time 9: 209.76
# +/- Seconds: 2385.62
# Predicted time 10: 209.79
# +/- Seconds: 1487.32

# %% [markdown]
# Kmeans with 4-fold cross validation

# %%
# %run raceTimePredictor.py
# Out:
# Load Data
#
# Start training
#
# Iteration  0
# train size:  205  test size:  1
# Train set evaluation
# Loss: 29.8267
# Root Mean Squared Error: 4.70263
#
# Test set evaluation
# Loss: 59.5378
# Root Mean Squared Error: 7.47976
#
# Iteration  1
# train size:  205  test size:  1
# Train set evaluation
# Loss: 30.1566
# Root Mean Squared Error: 4.72602
#
# Test set evaluation
# Loss: 19.374
# Root Mean Squared Error: 3.97166
#
# Iteration  2
# train size:  205  test size:  1
# Train set evaluation
# Loss: 26.8395
# Root Mean Squared Error: 4.33892
#
# Test set evaluation
# Loss: 5.10629
# Root Mean Squared Error: 0.247209
#
# Iteration  3
# train size:  205  test size:  1
# Train set evaluation
# Loss: 28.1645
# Root Mean Squared Error: 4.59337
#
# Test set evaluation
# Loss: 582.314
# Root Mean Squared Error: 24.0617
#
#
# Mean loss for 4-fold cross validation: 166.583
# Mean RMSE for 4-fold cross validation: 8.94007
#
# Predictions
#
#      dist  elev  hilly   cs  atl  ctl  isRace  avgVo2max   time  avgTrainPace
# 0    5000     0    0.0  0.0   30   45       1       43.5   17.5      3.023757
# 1    5000    70    0.1  0.2   30   45       1       43.5   19.0      3.023757
# 2    5000   150    0.3  1.5   30   45       1       43.5   22.0      3.023757
# 3   10000     0    0.0  0.0   30   45       1       43.5   36.5      3.023757
# 4   10000    70    0.3  0.5   30   45       1       43.5   39.0      3.023757
# 5   10000   150    0.5  1.5   30   45       1       43.5   41.0      3.023757
# 6   21097     0    0.0  0.0   30   45       1       43.5   79.0      3.023757
# 7   21097    70    0.3  0.5   30   45       1       43.5   81.0      3.023757
# 8   21097   150    0.4  1.5   30   50       1       43.5   85.0      3.023757
# 9   42195     0    0.0  0.0   30   50       1       43.5  170.0      3.023757
# 10  42195   150    0.5  1.0   30   50       1       43.5  185.0      3.023757
# Predicted time 0: 17.68
# +/- Seconds: 10.6
# Predicted time 1: 18.95
# +/- Seconds: -2.95
# Predicted time 2: 19.97
# +/- Seconds: -121.85
# Predicted time 3: 39.54
# +/- Seconds: 182.29
# Predicted time 4: 39.62
# +/- Seconds: 37.28
# Predicted time 5: 40.62
# +/- Seconds: -23.0
# Predicted time 6: 88.06
# +/- Seconds: 543.45
# Predicted time 7: 88.14
# +/- Seconds: 428.45
# Predicted time 8: 90.4
# +/- Seconds: 323.96
# Predicted time 9: 180.96
# +/- Seconds: 657.64
# Predicted time 10: 182.0
# +/- Seconds: -179.96

# %% [markdown]
# Athletes activities with 4-fold cross validation

# %%
# %run raceTimePredictor.py
# Out:
# Load Data
#
# Start training
#
# Iteration  0
# train size:  457  test size:  1
# Train set evaluation
# Loss: 306.324
# Root Mean Squared Error: 14.769
#
# Test set evaluation
# Loss: 1550.03
# Root Mean Squared Error: 38.2997
#
# Iteration  1
# train size:  457  test size:  1
# Train set evaluation
# Loss: 281.438
# Root Mean Squared Error: 13.6943
#
# Test set evaluation
# Loss: 1102.98
# Root Mean Squared Error: 31.7515
#
# Iteration  2
# train size:  457  test size:  1
# Train set evaluation
# Loss: 302.329
# Root Mean Squared Error: 15.4471
#
# Test set evaluation
# Loss: 154.578
# Root Mean Squared Error: 8.95042
#
# Iteration  3
# train size:  455  test size:  3
# Train set evaluation
# Loss: 355.274
# Root Mean Squared Error: 17.5824
#
# Test set evaluation
# Loss: 67.6084
# Root Mean Squared Error: 4.55181
#
#
# Mean loss for 4-fold cross validation: 718.799
# Mean RMSE for 4-fold cross validation: 20.8884
#
# Predictions
#
#      dist  elev  hilly   cs  atl  ctl  isRace  avgVo2max   time  avgTrainPace
# 0    5000     0    0.0  0.0   30   45       1       43.5   17.5      3.023757
# 1    5000    70    0.1  0.2   30   45       1       43.5   19.0      3.023757
# 2    5000   150    0.3  1.5   30   45       1       43.5   22.0      3.023757
# 3   10000     0    0.0  0.0   30   45       1       43.5   36.5      3.023757
# 4   10000    70    0.3  0.5   30   45       1       43.5   39.0      3.023757
# 5   10000   150    0.5  1.5   30   45       1       43.5   41.0      3.023757
# 6   21097     0    0.0  0.0   30   45       1       43.5   79.0      3.023757
# 7   21097    70    0.3  0.5   30   45       1       43.5   81.0      3.023757
# 8   21097   150    0.4  1.5   30   50       1       43.5   85.0      3.023757
# 9   42195     0    0.0  0.0   30   50       1       43.5  170.0      3.023757
# 10  42195   150    0.5  1.0   30   50       1       43.5  185.0      3.023757
# Predicted time 0: 23.97
# +/- Seconds: 387.96
# Predicted time 1: 25.63
# +/- Seconds: 397.64
# Predicted time 2: 27.67
# +/- Seconds: 340.49
# Predicted time 3: 40.1
# +/- Seconds: 215.8
# Predicted time 4: 42.53
# +/- Seconds: 211.96
# Predicted time 5: 44.64
# +/- Seconds: 218.3
# Predicted time 6: 91.2
# +/- Seconds: 731.95
# Predicted time 7: 94.49
# +/- Seconds: 809.24
# Predicted time 8: 98.41
# +/- Seconds: 804.46
# Predicted time 9: 213.69
# +/- Seconds: 2621.13
# Predicted time 10: 213.24
# +/- Seconds: 1694.43

# %% [markdown]
# Pre-training: Set, kmeans, Races. Own races in Set and All excluded

# %%
# %run raceTimePredictor.py
# Out:
# Pre-train Set
#
# train size:  4001
# Start training
#
# Pre-train kmeans
#
# train size:  203
# Start training
#
# Train races
#
# Start training
#
# Iteration  0
# train size:  5  test size:  1
# Train set evaluation
# Loss: 3.81327
# Root Mean Squared Error: 0.08882
#
# Test set evaluation
# Loss: 14.014
# Root Mean Squared Error: 3.19511
#
# Iteration  1
# train size:  5  test size:  1
# Train set evaluation
# Loss: 3.95276
# Root Mean Squared Error: 0.0515108
#
# Test set evaluation
# Loss: 422.44
# Root Mean Squared Error: 20.457
#
# Iteration  2
# train size:  5  test size:  1
# Train set evaluation
# Loss: 3.84026
# Root Mean Squared Error: 0.0518307
#
# Test set evaluation
# Loss: 469.312
# Root Mean Squared Error: 21.5749
#
# Iteration  3
# train size:  3  test size:  3
# Train set evaluation
# Loss: 4.40997
# Root Mean Squared Error: 0.524119
#
# Test set evaluation
# Loss: 829.356
# Root Mean Squared Error: 28.7267
#
#
# Mean loss for 4-fold cross validation: 433.781
# Mean RMSE for 4-fold cross validation: 18.4884
#
# Predictions
#
#      dist  elev  hilly   cs  atl  ctl  isRace  avgVo2max   time  avgTrainPace
# 0    5000     0    0.0  0.0   30   45       1       43.5   17.5      3.023757
# 1    5000    70    0.1  0.2   30   45       1       43.5   19.0      3.023757
# 2    5000   150    0.3  1.5   30   45       1       43.5   22.0      3.023757
# 3   10000     0    0.0  0.0   30   45       1       43.5   36.5      3.023757
# 4   10000    70    0.3  0.5   30   45       1       43.5   39.0      3.023757
# 5   10000   150    0.5  1.5   30   45       1       43.5   41.0      3.023757
# 6   21097     0    0.0  0.0   30   45       1       43.5   79.0      3.023757
# 7   21097    70    0.3  0.5   30   45       1       43.5   81.0      3.023757
# 8   21097   150    0.4  1.5   30   50       1       43.5   85.0      3.023757
# 9   42195     0    0.0  0.0   30   50       1       43.5  170.0      3.023757
# 10  42195   150    0.5  1.0   30   50       1       43.5  185.0      3.023757
# Predicted time 0: 90.13
# +/- Seconds: 4357.71
# Predicted time 1: 90.16
# +/- Seconds: 4269.71
# Predicted time 2: 90.24
# +/- Seconds: 4094.34
# Predicted time 3: 103.86
# +/- Seconds: 4041.88
# Predicted time 4: 103.94
# +/- Seconds: 3896.62
# Predicted time 5: 104.01
# +/- Seconds: 3780.88
# Predicted time 6: 134.35
# +/- Seconds: 3321.05
# Predicted time 7: 134.43
# +/- Seconds: 3205.79
# Predicted time 8: 153.77
# +/- Seconds: 4125.96
# Predicted time 9: 211.6
# +/- Seconds: 2495.83
# Predicted time 10: 211.74
# +/- Seconds: 1604.21

# %% [markdown]
# Pre-training: Set, kmeans. Own races in Set excluded.

# %%
# %run raceTimePredictor.py
# Out:
# Pre-train Set
#
# train size:  4001
# Start training
#
# Pre-train kmeans
#
# Start training
#
# Iteration  0
# train size:  205  test size:  1
# Train set evaluation
# Loss: 28.4673
# Root Mean Squared Error: 4.57316
#
# Test set evaluation
# Loss: 10.1163
# Root Mean Squared Error: 2.45091
#
# Iteration  1
# train size:  205  test size:  1
# Train set evaluation
# Loss: 28.6552
# Root Mean Squared Error: 4.55254
#
# Test set evaluation
# Loss: 6.13385
# Root Mean Squared Error: 1.34831
#
# Iteration  2
# train size:  205  test size:  1
# Train set evaluation
# Loss: 28.4255
# Root Mean Squared Error: 4.53185
#
# Test set evaluation
# Loss: 4.3171
# Root Mean Squared Error: 0.359532
#
# Iteration  3
# train size:  205  test size:  1
# Train set evaluation
# Loss: 28.0961
# Root Mean Squared Error: 4.58559
#
# Test set evaluation
# Loss: 566.085
# Root Mean Squared Error: 23.7219
#
#
# Mean loss for 4-fold cross validation: 146.663
# Mean RMSE for 4-fold cross validation: 6.97017
#
# Predictions
#
#      dist  elev  hilly   cs  atl  ctl  isRace  avgVo2max   time  avgTrainPace
# 0    5000     0    0.0  0.0   30   45       1       43.5   17.5      3.023757
# 1    5000    70    0.1  0.2   30   45       1       43.5   19.0      3.023757
# 2    5000   150    0.3  1.5   30   45       1       43.5   22.0      3.023757
# 3   10000     0    0.0  0.0   30   45       1       43.5   36.5      3.023757
# 4   10000    70    0.3  0.5   30   45       1       43.5   39.0      3.023757
# 5   10000   150    0.5  1.5   30   45       1       43.5   41.0      3.023757
# 6   21097     0    0.0  0.0   30   45       1       43.5   79.0      3.023757
# 7   21097    70    0.3  0.5   30   45       1       43.5   81.0      3.023757
# 8   21097   150    0.4  1.5   30   50       1       43.5   85.0      3.023757
# 9   42195     0    0.0  0.0   30   50       1       43.5  170.0      3.023757
# 10  42195   150    0.5  1.0   30   50       1       43.5  185.0      3.023757
# Predicted time 0: 17.65
# +/- Seconds: 9.03
# Predicted time 1: 19.08
# +/- Seconds: 4.84
# Predicted time 2: 20.37
# +/- Seconds: -97.54
# Predicted time 3: 39.52
# +/- Seconds: 180.92
# Predicted time 4: 39.83
# +/- Seconds: 49.82
# Predicted time 5: 41.08
# +/- Seconds: 4.82
# Predicted time 6: 88.04
# +/- Seconds: 542.53
# Predicted time 7: 88.36
# +/- Seconds: 441.42
# Predicted time 8: 90.93
# +/- Seconds: 355.7
# Predicted time 9: 181.04
# +/- Seconds: 662.68
# Predicted time 10: 182.54
# +/- Seconds: -147.78
